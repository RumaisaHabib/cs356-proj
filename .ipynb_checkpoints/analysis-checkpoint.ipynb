# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# # Setup

# %%
LABELS = list(pd.read_csv("taxonomy_v1_fixed.csv")["Name"])

# %%
def list2txt(arr,filename):
    with open(f'{filename}','w') as f:
        f.write('\n'.join(arr))

# %%
def replace_nums(label):
    if pd.isna(label):
        return None
    regex = r"[\s]?[0-9]+. "
    return re.sub(regex,"/",label)

# %%
def citm_add_slashes(label):
    if label != label:
        return np.nan
    labels = re.split(f'({"|".join(LABELS)})', label)
    labels = [l for l in labels if l and l!= " "]
    labels = labels[1:] # skip the first 
    label_string = "/".join(labels)
    label_string = "/" + label_string
    return label_string

# %%
citm_add_slashes("Web Browsers Computers & Electronics Software Web Browsers ")
# Out:
# '/Computers & Electronics/Software/Web Browsers'

# %%
def clean(df, dataset):
    if dataset == "manual":
        # 1. Remove NaN rows
        df = df.dropna(axis=0,how="all")
        
    elif dataset == "topics":
        # 1. Rename the pasted data from topics classifier
        df.rename({0:"Website URL", 1:"Unformatted Labels"},axis=1,inplace=True)
        df = df.set_index("Website URL")
        # 2. Remove the numbers and make format similar to manual
        df["Slash Labels"] = df["Unformatted Labels"].apply(replace_nums)
    
    elif dataset == "citm":
        df.rename({"0":"Label 1", "1":"Label 2", "2":"Label 3"},axis=1,inplace=True)
        df["Label 1"] = df["Label 1"].apply(citm_add_slashes)
        df["Label 2"] = df["Label 2"].apply(citm_add_slashes)
        df["Label 3"] = df["Label 3"].apply(citm_add_slashes)

        
    # Make everything lowercase
    df = df.apply(lambda x: x.astype(str).str.lower())
    return df

# %%
def extract_labels(label_str):
    '''
    Extract labels from a singular cell
    '''
    if pd.isna(label_str):
        return []
    # Remove the first empty one and remove empty
    labels = label_str.split("/")[1:]
    return [l for l in labels if l and l!= "  "]

def combine_labels(df, label_count):
    '''
    Returns new column with the distinct labels after theyve been extracted
    '''
    
    # Combine labels in all the rows
    label_list = df[f"Label 1"].apply(extract_labels)
    for i in range(2,label_count+1):
        label_list += df[f"Label {i}"].apply(extract_labels)
        
    label_list = label_list.apply(lambda arr : list(set(arr))) # Remove duplicates
    return label_list

# %%
manual_df = pd.read_csv("manual_labelling.csv",skiprows=3,index_col="Website URL")
manual_df
# Out:
#                                                                         Label 1  \
# Website URL
# trade.atlantiscex.com                  /Finance/Financial Planning & Management
# w2.brreg.no                                                                 NaN
# sadlierconnect.com                                  /Jobs & Education/Education
# webcampus.fdu.edu                                   /Jobs & Education/Education
# www.softbank.jp                /Finance/Investing/Currencies & Foreign Exchange
# ...                                                                         ...
# www.veepee.it                                                               NaN
# www.sephora.de                                                              NaN
# thothub.to                                                                  NaN
# www.freefilefillableforms.com                                               NaN
# www.jojobet732.com                                                          NaN
#
#                                                                          Label 2  \
# Website URL
# trade.atlantiscex.com           /Finance/Investing/Currencies & Foreign Exchange
# w2.brreg.no                                                                  NaN
# sadlierconnect.com             /Jobs & Education/Education/Colleges & Univers...
# webcampus.fdu.edu              /Jobs & Education/Education/Colleges & Univers...
# www.softbank.jp                                            /Finance/Credit Cards
# ...                                                                          ...
# www.veepee.it                                                                NaN
# www.sephora.de                                                               NaN
# thothub.to                                                                   NaN
# www.freefilefillableforms.com                                                NaN
# www.jojobet732.com                                                           NaN
#
#                                                                          Label 3
# Website URL
# trade.atlantiscex.com          /Business & Industrial/Advertising & Marketing...
# w2.brreg.no                                                                  NaN
# sadlierconnect.com                              /Reference/Educational Resources
# webcampus.fdu.edu                               /Reference/Educational Resources
# www.softbank.jp                /Finance/Accounting & Auditing/Tax Preparation...
# ...                                                                          ...
# www.veepee.it                                                                NaN
# www.sephora.de                                                               NaN
# thothub.to                                                                   NaN
# www.freefilefillableforms.com                                                NaN
# www.jojobet732.com                                                           NaN
#
# [10000 rows x 3 columns]

# %%
topics_df = pd.read_csv("topics_labelling.csv",header=None)
topics_df
# Out:
#                          0                                                  1
# 0    trade.atlantiscex.com                                     164. Investing
# 1       sadlierconnect.com  542. Primary & Secondary Schooling (K-12) 227....
# 2        webcampus.fdu.edu  1. Arts & entertainment 229. Colleges & univer...
# 3          www.softbank.jp  103. Business & industrial 218. Phone service ...
# 4             www.camif.fr                         103. Business & industrial
# ..                     ...                                                ...
# 603     www.weddingwire.in       196. Hobbies & leisure 254. People & society
# 604        kenyan-post.com                                          243. News
# 605       www.chipotle.com  173. Cooking & recipes 414. Food Service 463. ...
# 606       ww2.sunat.gob.pe                              239. Law & government
# 607       bsip.bnip.gov.pk                                       444. Banking
#
# [608 rows x 2 columns]

# %%
citm_df = pd.read_csv("citm_labelling.csv").rename({"Unnamed: 0": "Website URL"},axis=1).set_index("Website URL")
citm_df
# Out:
#                                                                          0  \
# Website URL
# suite.sogiscuola.com     Web Browsers Computers & Electronics Software ...
# loadedfiles.com             Networking Computers & Electronics Networking
# skemaraja.dephub.go.id                 People & Society People & Society
# easy-firmware.com                       Credit Cards Finance Credit Cards
# thesimplehelp.com                              Wrestling Sports Wrestling
# ...                                                                    ...
# www.dish.com                                     Pets Pets & Animals Pets
# www.adecco.fr            Consumer Electronics Computers & Electronics C...
# www.tgcom24.mediaset.it  Travel & Transportation Travel & Transportation
# www.anandabazar.com            Women's Clothing Shopping Women's Clothing
# www.thetimes.co.uk       Web Browsers Computers & Electronics Software ...
#
#                                                                          1  \
# Website URL
# suite.sogiscuola.com                                                   NaN
# loadedfiles.com            Online Video Arts & Entertainment Online Video
# skemaraja.dephub.go.id   Face & Body Care Beauty & Fitness Face & Body ...
# easy-firmware.com        Consumer Electronics Computers & Electronics C...
# thesimplehelp.com                          Pets & Animals Pets & Animals
# ...                                                                    ...
# www.dish.com                   Women's Clothing Shopping Women's Clothing
# www.adecco.fr                Smart Phones Internet & Telecom Smart Phones
# www.tgcom24.mediaset.it  Musical Instruments Arts & Entertainment Music...
# www.anandabazar.com                            Wrestling Sports Wrestling
# www.thetimes.co.uk       Ecology & Environment Science Ecology & Enviro...
#
#                                                                          2
# Website URL
# suite.sogiscuola.com                                                   NaN
# loadedfiles.com                       Outdoors Hobbies & Leisure Outdoors
# skemaraja.dephub.go.id   Advertising & Marketing Business & Industrial ...
# easy-firmware.com               Software Computers & Electronics Software
# thesimplehelp.com                       Gardening Home & Garden Gardening
# ...                                                                    ...
# www.dish.com                               Pets & Animals Pets & Animals
# www.adecco.fr                  Women's Clothing Shopping Women's Clothing
# www.tgcom24.mediaset.it      Vehicle Shows Autos & Vehicles Vehicle Shows
# www.anandabazar.com                    People & Society People & Society
# www.thetimes.co.uk                    Outdoors Hobbies & Leisure Outdoors
#
# [78 rows x 3 columns]

# %%
manual_df = clean(manual_df, "manual")
list2txt(list(manual_df.index), "urls.txt")

if "Labels" not in manual_df.columns:
    manual_df["Labels"] = combine_labels(manual_df, 3)
manual_df = manual_df[["Labels"]] # Dont need the other labels now

# %%
manual_df
# Out:
#                                                                   Labels
# Website URL
# trade.atlantiscex.com  [currencies & foreign exchange, finance, inves...
# sadlierconnect.com     [education, reference, colleges & universities...
# webcampus.fdu.edu      [education, reference, colleges & universities...
# www.softbank.jp        [accounting & auditing, currencies & foreign e...
# www.camif.fr           [home improvement, home & garden, household su...
# ...                                                                  ...
# www.weddingwire.in     [arts & entertainment, weddings, hobbies & lei...
# kenyan-post.com                   [online communities, news, local news]
# www.chipotle.com       [cooking & recipes, business & industrial, foo...
# ww2.sunat.gob.pe               [legal, legal services, law & government]
# bsip.bnip.gov.pk               [legal, legal services, law & government]
#
# [608 rows x 1 columns]

# %%
topics_df = clean(topics_df,"topics")
if "Labels" not in topics_df.columns:
    topics_df["Labels"] = topics_df["Slash Labels"].apply(extract_labels)
topics_df = topics_df[["Labels"]]
topics_df
# Out:
#                                                                   Labels
# Website URL
# trade.atlantiscex.com                                        [investing]
# sadlierconnect.com     [primary & secondary schooling (k-12), education]
# webcampus.fdu.edu        [arts & entertainment, colleges & universities]
# www.softbank.jp         [business & industrial, phone service providers]
# www.camif.fr                                     [business & industrial]
# ...                                                                  ...
# www.weddingwire.in                 [hobbies & leisure, people & society]
# kenyan-post.com                                                   [news]
# www.chipotle.com       [cooking & recipes, food service, fast food, r...
# ww2.sunat.gob.pe                                      [law & government]
# bsip.bnip.gov.pk                                               [banking]
#
# [608 rows x 1 columns]

# %%
citm_df = clean(citm_df, "citm")
if "Labels" not in citm_df.columns:
    citm_df["Labels"] = combine_labels(citm_df, 3)
citm_df = citm_df[["Labels"]] # Dont need the other labels now

# %%
citm_df
# Out:
#                                                                     Labels
# Website URL
# suite.sogiscuola.com     [computers & electronics, software, web browsers]
# loadedfiles.com          [networking, outdoors, computers & electronics...
# skemaraja.dephub.go.id   [beauty & fitness, people & society, advertisi...
# easy-firmware.com        [consumer electronics, finance, credit cards, ...
# thesimplehelp.com        [gardening, pets & animals, home & garden, wre...
# ...                                                                    ...
# www.dish.com             [shopping, pets, pets & animals, women's cloth...
# www.adecco.fr            [consumer electronics, women's clothing, smart...
# www.tgcom24.mediaset.it  [music & audio, travel & transportation, music...
# www.anandabazar.com      [people & society, women's clothing, shopping,...
# www.thetimes.co.uk       [web browsers, science, outdoors, computers & ...
#
# [78 rows x 1 columns]

# %% [markdown]
# # Comparison

# %% [markdown]
# ## Match counts

# %%
def correct_label(test, truth):
    '''
    Given a test list (topics label, usually), do all the labels appear in the truth list?
    If its empty, it is not a match. Flag as empty.
    '''
    if not test:
        return False, True # Not a match, empty test
    return all(i in truth for i in test), False

# %%
combined_df = topics_df
combined_df.rename({"Labels":"Topics"},axis=1,inplace=True)
combined_df["Manual"] = manual_df["Labels"]
combined_df
# Out:
#                                                                   Topics  \
# Website URL
# trade.atlantiscex.com                                        [investing]
# sadlierconnect.com     [primary & secondary schooling (k-12), education]
# webcampus.fdu.edu        [arts & entertainment, colleges & universities]
# www.softbank.jp         [business & industrial, phone service providers]
# www.camif.fr                                     [business & industrial]
# ...                                                                  ...
# www.weddingwire.in                 [hobbies & leisure, people & society]
# kenyan-post.com                                                   [news]
# www.chipotle.com       [cooking & recipes, food service, fast food, r...
# ww2.sunat.gob.pe                                      [law & government]
# bsip.bnip.gov.pk                                               [banking]
#
#                                                                   Manual
# Website URL
# trade.atlantiscex.com  [currencies & foreign exchange, finance, inves...
# sadlierconnect.com     [education, reference, colleges & universities...
# webcampus.fdu.edu      [education, reference, colleges & universities...
# www.softbank.jp        [accounting & auditing, currencies & foreign e...
# www.camif.fr           [home improvement, home & garden, household su...
# ...                                                                  ...
# www.weddingwire.in     [arts & entertainment, weddings, hobbies & lei...
# kenyan-post.com                   [online communities, news, local news]
# www.chipotle.com       [cooking & recipes, business & industrial, foo...
# ww2.sunat.gob.pe               [legal, legal services, law & government]
# bsip.bnip.gov.pk               [legal, legal services, law & government]
#
# [608 rows x 2 columns]

# %%
combined_df[["Match", "Empty"]] = combined_df.apply(lambda x: correct_label(x["Topics"], x["Manual"]), axis=1,result_type='expand')
combined_df.to_csv("combined.csv")
combined_df
# Out:
#                                                                   Topics  \
# Website URL
# trade.atlantiscex.com                                        [investing]
# sadlierconnect.com     [primary & secondary schooling (k-12), education]
# webcampus.fdu.edu        [arts & entertainment, colleges & universities]
# www.softbank.jp         [business & industrial, phone service providers]
# www.camif.fr                                     [business & industrial]
# ...                                                                  ...
# www.weddingwire.in                 [hobbies & leisure, people & society]
# kenyan-post.com                                                   [news]
# www.chipotle.com       [cooking & recipes, food service, fast food, r...
# ww2.sunat.gob.pe                                      [law & government]
# bsip.bnip.gov.pk                                               [banking]
#
#                                                                   Manual  \
# Website URL
# trade.atlantiscex.com  [currencies & foreign exchange, finance, inves...
# sadlierconnect.com     [education, reference, colleges & universities...
# webcampus.fdu.edu      [education, reference, colleges & universities...
# www.softbank.jp        [accounting & auditing, currencies & foreign e...
# www.camif.fr           [home improvement, home & garden, household su...
# ...                                                                  ...
# www.weddingwire.in     [arts & entertainment, weddings, hobbies & lei...
# kenyan-post.com                   [online communities, news, local news]
# www.chipotle.com       [cooking & recipes, business & industrial, foo...
# ww2.sunat.gob.pe               [legal, legal services, law & government]
# bsip.bnip.gov.pk               [legal, legal services, law & government]
#
#                        Match  Empty
# Website URL
# trade.atlantiscex.com   True  False
# sadlierconnect.com     False  False
# webcampus.fdu.edu      False  False
# www.softbank.jp        False  False
# www.camif.fr           False  False
# ...                      ...    ...
# www.weddingwire.in     False  False
# kenyan-post.com         True  False
# www.chipotle.com       False  False
# ww2.sunat.gob.pe        True  False
# bsip.bnip.gov.pk       False  False
#
# [608 rows x 4 columns]

# %%
combined_df["Match"].value_counts()
# Out:
# False    450
# True     158
# Name: Match, dtype: int64

# %%
print("Percentage match")
temp = combined_df["Match"].value_counts()
(temp[True])/(temp[True]+temp[False]) * 100
# Out:
# Percentage match
# 25.986842105263158

# %%
print("Percent empty")
temp = combined_df["Empty"].value_counts()
(temp[True])/(temp[True]+temp[False]) * 100
# Out:
# Percent empty
# 13.486842105263158

# %% [markdown]
# ### Excluding empty ones

# %%
combined_df[~combined_df.Empty]["Match"].value_counts()
# Out:
# False    368
# True     158
# Name: Match, dtype: int64

# %%
print("Percentage match")
combined_wo_empty_df = combined_df[~combined_df.Empty]
temp = combined_wo_empty_df["Match"].value_counts()
(temp[True])/(temp[True]+temp[False]) * 100
# Out:
# Percentage match
# 30.038022813688215

# %%
combined_wo_empty_df[~combined_wo_empty_df["Match"]].to_csv("mismatches_topics.csv")
combined_wo_empty_df
# Out:
#                                                                   Topics  \
# Website URL
# trade.atlantiscex.com                                        [investing]
# sadlierconnect.com     [primary & secondary schooling (k-12), education]
# webcampus.fdu.edu        [arts & entertainment, colleges & universities]
# www.softbank.jp         [business & industrial, phone service providers]
# www.camif.fr                                     [business & industrial]
# ...                                                                  ...
# www.weddingwire.in                 [hobbies & leisure, people & society]
# kenyan-post.com                                                   [news]
# www.chipotle.com       [cooking & recipes, food service, fast food, r...
# ww2.sunat.gob.pe                                      [law & government]
# bsip.bnip.gov.pk                                               [banking]
#
#                                                                   Manual  \
# Website URL
# trade.atlantiscex.com  [currencies & foreign exchange, finance, inves...
# sadlierconnect.com     [education, reference, colleges & universities...
# webcampus.fdu.edu      [education, reference, colleges & universities...
# www.softbank.jp        [accounting & auditing, currencies & foreign e...
# www.camif.fr           [home improvement, home & garden, household su...
# ...                                                                  ...
# www.weddingwire.in     [arts & entertainment, weddings, hobbies & lei...
# kenyan-post.com                   [online communities, news, local news]
# www.chipotle.com       [cooking & recipes, business & industrial, foo...
# ww2.sunat.gob.pe               [legal, legal services, law & government]
# bsip.bnip.gov.pk               [legal, legal services, law & government]
#
#                        Match  Empty
# Website URL
# trade.atlantiscex.com   True  False
# sadlierconnect.com     False  False
# webcampus.fdu.edu      False  False
# www.softbank.jp        False  False
# www.camif.fr           False  False
# ...                      ...    ...
# www.weddingwire.in     False  False
# kenyan-post.com         True  False
# www.chipotle.com       False  False
# ww2.sunat.gob.pe        True  False
# bsip.bnip.gov.pk       False  False
#
# [526 rows x 4 columns]

# %% [markdown]
# ## Particular categories

# %%
combined_mismatch = combined_df[~combined_df.Match]
combined_mismatch
# Out:
#                                                                Topics  \
# Website URL
# sadlierconnect.com  [primary & secondary schooling (k-12), education]
# webcampus.fdu.edu     [arts & entertainment, colleges & universities]
# www.softbank.jp      [business & industrial, phone service providers]
# www.camif.fr                                  [business & industrial]
# codsaya.com                                                    [news]
# ...                                                               ...
# tokuvn.com                                       [comics & animation]
# 2gis.ua                                                            []
# www.weddingwire.in              [hobbies & leisure, people & society]
# www.chipotle.com    [cooking & recipes, food service, fast food, r...
# bsip.bnip.gov.pk                                            [banking]
#
#                                                                Manual  Match  \
# Website URL
# sadlierconnect.com  [education, reference, colleges & universities...  False
# webcampus.fdu.edu   [education, reference, colleges & universities...  False
# www.softbank.jp     [accounting & auditing, currencies & foreign e...  False
# www.camif.fr        [home improvement, home & garden, household su...  False
# codsaya.com         [card games, travel & transportation, tourist ...  False
# ...                                                               ...    ...
# tokuvn.com          [arts & entertainment, entertainment industry,...  False
# 2gis.ua             [travel & transportation, travel guides & trav...  False
# www.weddingwire.in  [arts & entertainment, weddings, hobbies & lei...  False
# www.chipotle.com    [cooking & recipes, business & industrial, foo...  False
# bsip.bnip.gov.pk            [legal, legal services, law & government]  False
#
#                     Empty
# Website URL
# sadlierconnect.com  False
# webcampus.fdu.edu   False
# www.softbank.jp     False
# www.camif.fr        False
# codsaya.com         False
# ...                   ...
# tokuvn.com          False
# 2gis.ua              True
# www.weddingwire.in  False
# www.chipotle.com    False
# bsip.bnip.gov.pk    False
#
# [450 rows x 4 columns]

# %%
combined_mismatch_non_empty = combined_wo_empty_df[~combined_wo_empty_df.Match]
combined_mismatch_non_empty
# Out:
#                                                                Topics  \
# Website URL
# sadlierconnect.com  [primary & secondary schooling (k-12), education]
# webcampus.fdu.edu     [arts & entertainment, colleges & universities]
# www.softbank.jp      [business & industrial, phone service providers]
# www.camif.fr                                  [business & industrial]
# codsaya.com                                                    [news]
# ...                                                               ...
# quizzclub.com                                  [arts & entertainment]
# tokuvn.com                                       [comics & animation]
# www.weddingwire.in              [hobbies & leisure, people & society]
# www.chipotle.com    [cooking & recipes, food service, fast food, r...
# bsip.bnip.gov.pk                                            [banking]
#
#                                                                Manual  Match  \
# Website URL
# sadlierconnect.com  [education, reference, colleges & universities...  False
# webcampus.fdu.edu   [education, reference, colleges & universities...  False
# www.softbank.jp     [accounting & auditing, currencies & foreign e...  False
# www.camif.fr        [home improvement, home & garden, household su...  False
# codsaya.com         [card games, travel & transportation, tourist ...  False
# ...                                                               ...    ...
# quizzclub.com                 [online communities, games, card games]  False
# tokuvn.com          [arts & entertainment, entertainment industry,...  False
# www.weddingwire.in  [arts & entertainment, weddings, hobbies & lei...  False
# www.chipotle.com    [cooking & recipes, business & industrial, foo...  False
# bsip.bnip.gov.pk            [legal, legal services, law & government]  False
#
#                     Empty
# Website URL
# sadlierconnect.com  False
# webcampus.fdu.edu   False
# www.softbank.jp     False
# www.camif.fr        False
# codsaya.com         False
# ...                   ...
# quizzclub.com       False
# tokuvn.com          False
# www.weddingwire.in  False
# www.chipotle.com    False
# bsip.bnip.gov.pk    False
#
# [368 rows x 4 columns]

# %%
combined_empty = combined_df[combined_df.Empty]
combined_empty
# Out:
#                         Topics  \
# Website URL
# www.indiansexhub.com        []
# m.4d88.asia                 []
# aiotechnical.com            []
# www.bhajandiary.com         []
# www.al-hamdoulillah.com     []
# ...                        ...
# wwwxvideo.org               []
# qualp.com.br                []
# www.xxxsexpic.me            []
# socinquenta.com.br          []
# 2gis.ua                     []
#
#                                                                     Manual  \
# Website URL
# www.indiansexhub.com     [arts & entertainment, entertainment industry,...
# m.4d88.asia              [forum & chat providers, live sporting events,...
# aiotechnical.com         [finance, insurance, acting & theater, compute...
# www.bhajandiary.com      [arts & entertainment, online communities, dat...
# www.al-hamdoulillah.com  [forum & chat providers, online communities, s...
# ...                                                                    ...
# wwwxvideo.org            [entertainment industry, social networks, arts...
# qualp.com.br             [travel & transportation, travel guides & trav...
# www.xxxsexpic.me         [photographic & digital arts, visual art & des...
# socinquenta.com.br       [arts & entertainment, entertainment industry,...
# 2gis.ua                  [travel & transportation, travel guides & trav...
#
#                          Match  Empty
# Website URL
# www.indiansexhub.com     False   True
# m.4d88.asia              False   True
# aiotechnical.com         False   True
# www.bhajandiary.com      False   True
# www.al-hamdoulillah.com  False   True
# ...                        ...    ...
# wwwxvideo.org            False   True
# qualp.com.br             False   True
# www.xxxsexpic.me         False   True
# socinquenta.com.br       False   True
# 2gis.ua                  False   True
#
# [82 rows x 4 columns]

# %%
def category_mismatch_absolute_plot(df, figsize, count):
    '''
    Given a filtered dataframe with labels, plot a bar plot of the count
    '''
    labels = df["Manual"].explode().value_counts() # explode separates the list
    to_plot = pd.DataFrame(labels)
    to_plot.head(count).plot(kind="barh",figsize=figsize)

# %% [markdown]
# ### Which are mismatches OR empty?

# %%
category_mismatch_absolute_plot(combined_mismatch, (5,3), 10)

# %% [markdown]
# ### Which are mismatches ONLY?

# %%
category_mismatch_absolute_plot(combined_mismatch_non_empty, (5,3), 10)

# %% [markdown]
# ### Which are empty?

# %%
category_mismatch_absolute_plot(combined_empty, (5,3), 10)

# %% [markdown]
# #### But arts & entertainment is the most prominent label anyway. Look at the percentage of total labels

# %%
def category_mismatch_perc_plot(df, full_count_df, figsize, count):
    '''
    Given a filtered and unfiltered dataframe with labels, plot a bar plot of the percentage of that label that was mismatched
    Filter out the ones that have less than 10 occurrances 
    '''
    all_labels = full_count_df["Manual"].explode().value_counts()
    all_labels = all_labels[all_labels>10]
    mismatch_labels = df["Manual"].explode().value_counts()
    
    to_plot = pd.DataFrame(mismatch_labels/all_labels * 100).sort_values("Manual",ascending=False)
    to_plot.head(count).plot(kind="barh",figsize=figsize)

# %% [markdown]
# ### Which are mismatches OR empty?

# %%
category_mismatch_perc_plot(combined_mismatch, combined_df, (5,3), 10)

# %% [markdown]
# ### Which are mismatches ONLY?

# %%
category_mismatch_perc_plot(combined_mismatch_non_empty, combined_df,(5,3), 10)

# %% [markdown]
# ### Which are empty?

# %%
category_mismatch_perc_plot(combined_empty, combined_df,(5,3), 10)

# %% [markdown]
# ## Other approaches

# %% [markdown]
# ### CITM

# %%
combined_citm_df = citm_df
combined_citm_df.rename({"Labels":"CITM"},axis=1,inplace=True)
combined_citm_df["Manual"] = manual_df["Labels"]
combined_citm_df
combined_citm_df[["Match", "Empty"]] = combined_citm_df.apply(lambda x: correct_label(x["CITM"], x["Manual"]), axis=1,result_type='expand')
combined_citm_df
# Out:
#                                                                       CITM  \
# Website URL
# suite.sogiscuola.com     [computers & electronics, software, web browsers]
# loadedfiles.com          [networking, outdoors, computers & electronics...
# skemaraja.dephub.go.id   [beauty & fitness, people & society, advertisi...
# easy-firmware.com        [consumer electronics, finance, credit cards, ...
# thesimplehelp.com        [gardening, pets & animals, home & garden, wre...
# ...                                                                    ...
# www.dish.com             [shopping, pets, pets & animals, women's cloth...
# www.adecco.fr            [consumer electronics, women's clothing, smart...
# www.tgcom24.mediaset.it  [music & audio, travel & transportation, music...
# www.anandabazar.com      [people & society, women's clothing, shopping,...
# www.thetimes.co.uk       [web browsers, science, outdoors, computers & ...
#
#                                                                     Manual  \
# Website URL
# suite.sogiscuola.com     [education, web apps & online tools, distance ...
# loadedfiles.com          [computers & electronics, internet & telecom, ...
# skemaraja.dephub.go.id   [travel & transportation, hotels & accommodati...
# easy-firmware.com        [forum & chat providers, smart phones, compute...
# thesimplehelp.com        [forum & chat providers, jobs & education, job...
# ...                                                                    ...
# www.dish.com             [arts & entertainment, live sporting events, t...
# www.adecco.fr            [news, internet & telecom, web apps & online t...
# www.tgcom24.mediaset.it  [news, politics, tv shows & programs, arts & e...
# www.anandabazar.com      [forum & chat providers, news, politics, local...
# www.thetimes.co.uk          [arts & entertainment, sports, news, politics]
#
#                          Match  Empty
# Website URL
# suite.sogiscuola.com     False  False
# loadedfiles.com          False  False
# skemaraja.dephub.go.id   False  False
# easy-firmware.com        False  False
# thesimplehelp.com        False  False
# ...                        ...    ...
# www.dish.com             False  False
# www.adecco.fr            False  False
# www.tgcom24.mediaset.it  False  False
# www.anandabazar.com      False  False
# www.thetimes.co.uk       False  False
#
# [78 rows x 4 columns]

# %%
print("Percentage match")
temp = combined_citm_df["Match"].value_counts()
(temp[True])/(temp[True]+temp[False]) * 100
# Out:
# Percentage match
# 3.8461538461538463

# %%
combined_citm_df[combined_citm_df["Match"]==False].to_csv("mismatches_citm.csv")
combined_citm_df[combined_citm_df["Match"]==False]
# Out:
#                                                                       CITM  \
# Website URL
# suite.sogiscuola.com     [computers & electronics, software, web browsers]
# loadedfiles.com          [networking, outdoors, computers & electronics...
# skemaraja.dephub.go.id   [beauty & fitness, people & society, advertisi...
# easy-firmware.com        [consumer electronics, finance, credit cards, ...
# thesimplehelp.com        [gardening, pets & animals, home & garden, wre...
# ...                                                                    ...
# www.dish.com             [shopping, pets, pets & animals, women's cloth...
# www.adecco.fr            [consumer electronics, women's clothing, smart...
# www.tgcom24.mediaset.it  [music & audio, travel & transportation, music...
# www.anandabazar.com      [people & society, women's clothing, shopping,...
# www.thetimes.co.uk       [web browsers, science, outdoors, computers & ...
#
#                                                                     Manual  \
# Website URL
# suite.sogiscuola.com     [education, web apps & online tools, distance ...
# loadedfiles.com          [computers & electronics, internet & telecom, ...
# skemaraja.dephub.go.id   [travel & transportation, hotels & accommodati...
# easy-firmware.com        [forum & chat providers, smart phones, compute...
# thesimplehelp.com        [forum & chat providers, jobs & education, job...
# ...                                                                    ...
# www.dish.com             [arts & entertainment, live sporting events, t...
# www.adecco.fr            [news, internet & telecom, web apps & online t...
# www.tgcom24.mediaset.it  [news, politics, tv shows & programs, arts & e...
# www.anandabazar.com      [forum & chat providers, news, politics, local...
# www.thetimes.co.uk          [arts & entertainment, sports, news, politics]
#
#                          Match  Empty
# Website URL
# suite.sogiscuola.com     False  False
# loadedfiles.com          False  False
# skemaraja.dephub.go.id   False  False
# easy-firmware.com        False  False
# thesimplehelp.com        False  False
# ...                        ...    ...
# www.dish.com             False  False
# www.adecco.fr            False  False
# www.tgcom24.mediaset.it  False  False
# www.anandabazar.com      False  False
# www.thetimes.co.uk       False  False
#
# [75 rows x 4 columns]
